# %% [markdown]
# # XArray Manipulation

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr


xr.set_options(keep_attrs=True, display_expand_data=False)
np.set_printoptions(threshold=10, edgeitems=2)

# %% [markdown]
# ## 1.- Exploring a new dataset

# %% [markdown]
# ### Loading dataset

# %%
dataset = xr.tutorial.open_dataset('rasm')
dataset
# Out:
# <xarray.Dataset> Size: 17MB
# Dimensions:  (time: 36, y: 205, x: 275)
# Coordinates:
#   * time     (time) object 288B 1980-09-16 12:00:00 ... 1983-08-17 00:00:00
#     xc       (y, x) float64 451kB ...
#     yc       (y, x) float64 451kB ...
# Dimensions without coordinates: y, x
# Data variables:
#     Tair     (time, y, x) float64 16MB ...
# Attributes:
#     title:                     /workspace/jhamman/processed/R1002RBRxaaa01a/l...
#     institution:               U.W.
#     source:                    RACM R1002RBRxaaa01a
#     output_frequency:          daily
#     output_mode:               averaged
#     convention:                CF-1.4
#     references:                Based on the initial model of Liang et al., 19...
#     comment:                   Output from the Variable Infiltration Capacity...
#     nco_openmp_thread_number:  1
#     NCO:                       netCDF Operators version 4.7.9 (Homepage = htt...
#     history:                   Fri Aug  7 17:57:38 2020: ncatted -a bounds,,d...

# %% [markdown]
# ### Dataset Variables

# %%
print(dataset.data_vars)
# Out:
# Data variables:
#     Tair     (time, y, x) float64 16MB ...

# %% [markdown]
# ### Dataset Dimensions

# %%
print(dataset.dims)
# Out:
# FrozenMappingWarningOnValuesAccess({'time': 36, 'y': 205, 'x': 275})

# %% [markdown]
# ### Opening Tair Variable (air temperature)

# %%
tair = dataset.Tair
tair
# Out:
# <xarray.DataArray 'Tair' (time: 36, y: 205, x: 275)> Size: 16MB
# [2029500 values with dtype=float64]
# Coordinates:
#   * time     (time) object 288B 1980-09-16 12:00:00 ... 1983-08-17 00:00:00
#     xc       (y, x) float64 451kB ...
#     yc       (y, x) float64 451kB ...
# Dimensions without coordinates: y, x
# Attributes:
#     units:           C
#     long_name:       Surface air temperature
#     type_preferred:  double
#     time_rep:        instantaneous

# %% [markdown]
# ### Tair Values

# %%
tair.values
# Out:
# array([[[        nan,         nan, ...,         nan,         nan],
#         [        nan,         nan, ...,         nan,         nan],
#         ...,
#         [        nan,         nan, ..., 26.80261869, 27.08603517],
#         [        nan,         nan, ..., 26.56473862, 26.73064933]],
#
#        [[        nan,         nan, ...,         nan,         nan],
#         [        nan,         nan, ...,         nan,         nan],
#         ...,
#         [        nan,         nan, ..., 24.29623992, 24.61422421],
#         [        nan,         nan, ..., 24.29967705, 24.45439921]],
#
#        ...,
#
#        [[        nan,         nan, ...,         nan,         nan],
#         [        nan,         nan, ...,         nan,         nan],
#         ...,
#         [        nan,         nan, ..., 27.31104941, 27.67387171],
#         [        nan,         nan, ..., 27.0088944 , 27.23017976]],
#
#        [[        nan,         nan, ...,         nan,         nan],
#         [        nan,         nan, ...,         nan,         nan],
#         ...,
#         [        nan,         nan, ..., 28.42273578, 28.68721201],
#         [        nan,         nan, ..., 28.18595533, 28.20753022]]])

# %% [markdown]
# ### Tair Dimensions

# %%
tair.dims
# Out:
# ('time', 'y', 'x')

# %% [markdown]
# ### Tair Coordinates

# %%
tair.coords
# Out:
# Coordinates:
#   * time     (time) object 288B 1980-09-16 12:00:00 ... 1983-08-17 00:00:00
#     xc       (y, x) float64 451kB ...
#     yc       (y, x) float64 451kB ...

# %%
### Tair
